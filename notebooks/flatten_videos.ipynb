# %%
from glob import glob

paths = glob("../persist/blob/channels/*/video_list/*")

paths
# Out:
# ['../persist/blob/channels/UCpVm7bg6pXKo1Pr6k5kxG9A/video_list/videos-pt-2.json',
#  '../persist/blob/channels/UCpVm7bg6pXKo1Pr6k5kxG9A/video_list/videos-pt-4.json',
#  '../persist/blob/channels/UCpVm7bg6pXKo1Pr6k5kxG9A/video_list/videos-pt-5.json',
#  '../persist/blob/channels/UCpVm7bg6pXKo1Pr6k5kxG9A/video_list/videos-pt-1.json',
#  '../persist/blob/channels/UCpVm7bg6pXKo1Pr6k5kxG9A/video_list/videos-pt-3.json',
#  '../persist/blob/channels/UCpVm7bg6pXKo1Pr6k5kxG9A/video_list/videos-pt-0.json']

# %%
import json

vid_data = []
for file in paths:
    with open(file) as js_io:
        vid_dict = json.load(js_io)
    vid_info = [x["snippet"] | x["contentDetails"] for x in vid_dict["items"]]
    vid_data.extend(vid_info)

# %%
import pandas as pd
vid_df = pd.DataFrame(vid_data)
vid_df
# Out:
#               publishedAt                 channelId  \
# 0    2021-11-13T12:59:45Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# 1    2021-11-12T15:59:46Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# 2    2021-11-12T15:04:50Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# 3    2021-11-12T14:59:52Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# 4    2021-11-12T14:59:52Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# ..                    ...                       ...
# 295  2022-03-29T11:59:48Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# 296  2022-03-26T11:59:51Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# 297  2022-03-25T14:59:53Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# 298  2022-03-24T13:29:47Z  UCpVm7bg6pXKo1Pr6k5kxG9A
# 299  2022-03-23T16:59:50Z  UCpVm7bg6pXKo1Pr6k5kxG9A
#
#                                                  title  \
# 0    Slowly into Secret Scotland | National Geographic
# 1           A Belly Full of Cocaine | Locked Up Abroad
# 2    America the Beautiful | Official Trailer | Dis...
# 3    Welcome to Earth | Official Trailer - Audio De...
# 4     Welcome to Earth | Official Trailer #2 | Disney+
# ..                                                 ...
# 295  Queens of the High Seas | Podcast | Overheard ...
# 296              Bin Laden's Hard Drive | Full Episode
# 297               Summer of Soul | National Geographic
# 298  Exploring Iceland in Winter | National Geographic
# 299  Why Does Evil Exist? (Full Episode) | The Stor...
#
#                                            description  \
# 0    Join National Geographic travel photographer M...
# 1    Ainsley, a UK citizen, has ingested 86 pellets...
# 2    Explore the stunning spaces that define Americ...
# 3    Join Will Smith on an extraordinary, once-in-a...
# 4    Follow Will Smith to the ends of the Earth, li...
# ..                                                 ...
# 295  Yo ho, a pirate’s life for she! Legends of Bla...
# 296  Newly declassified hard drives taken from the ...
# 297  Nominated for Best Documentary at this Sunday’...
# 298  National Geographic Photographer Kiliii Yuyan ...
# 299  Where does evil come from? Morgan sets out to ...
#
#                                             thumbnails         channelTitle  \
# 0    {'default': {'url': 'https://i.ytimg.com/vi/IR...  National Geographic
# 1    {'default': {'url': 'https://i.ytimg.com/vi/tE...  National Geographic
# 2    {'default': {'url': 'https://i.ytimg.com/vi/ZA...  National Geographic
# 3    {'default': {'url': 'https://i.ytimg.com/vi/9E...  National Geographic
# 4    {'default': {'url': 'https://i.ytimg.com/vi/vM...  National Geographic
# ..                                                 ...                  ...
# 295  {'default': {'url': 'https://i.ytimg.com/vi/gH...  National Geographic
# 296  {'default': {'url': 'https://i.ytimg.com/vi/4W...  National Geographic
# 297  {'default': {'url': 'https://i.ytimg.com/vi/Bt...  National Geographic
# 298  {'default': {'url': 'https://i.ytimg.com/vi/Wo...  National Geographic
# 299  {'default': {'url': 'https://i.ytimg.com/vi/ok...  National Geographic
#
#                    playlistId  position  \
# 0    UUpVm7bg6pXKo1Pr6k5kxG9A       100
# 1    UUpVm7bg6pXKo1Pr6k5kxG9A       101
# 2    UUpVm7bg6pXKo1Pr6k5kxG9A       102
# 3    UUpVm7bg6pXKo1Pr6k5kxG9A       103
# 4    UUpVm7bg6pXKo1Pr6k5kxG9A       104
# ..                        ...       ...
# 295  UUpVm7bg6pXKo1Pr6k5kxG9A        45
# 296  UUpVm7bg6pXKo1Pr6k5kxG9A        46
# 297  UUpVm7bg6pXKo1Pr6k5kxG9A        47
# 298  UUpVm7bg6pXKo1Pr6k5kxG9A        48
# 299  UUpVm7bg6pXKo1Pr6k5kxG9A        49
#
#                                             resourceId videoOwnerChannelTitle  \
# 0    {'kind': 'youtube#video', 'videoId': 'IRPSH1M_...    National Geographic
# 1    {'kind': 'youtube#video', 'videoId': 'tESd_GkK...    National Geographic
# 2    {'kind': 'youtube#video', 'videoId': 'ZADCqbRr...    National Geographic
# 3    {'kind': 'youtube#video', 'videoId': '9EiFxvBd...    National Geographic
# 4    {'kind': 'youtube#video', 'videoId': 'vMZuibGS...    National Geographic
# ..                                                 ...                    ...
# 295  {'kind': 'youtube#video', 'videoId': 'gHZcW1Vn...    National Geographic
# 296  {'kind': 'youtube#video', 'videoId': '4W_P_Yxh...    National Geographic
# 297  {'kind': 'youtube#video', 'videoId': 'BtCLZbZS...    National Geographic
# 298  {'kind': 'youtube#video', 'videoId': 'WoTzliYi...    National Geographic
# 299  {'kind': 'youtube#video', 'videoId': 'ok8NYX1d...    National Geographic
#
#           videoOwnerChannelId      videoId      videoPublishedAt
# 0    UCpVm7bg6pXKo1Pr6k5kxG9A  IRPSH1M_NAw  2021-11-13T12:59:45Z
# 1    UCpVm7bg6pXKo1Pr6k5kxG9A  tESd_GkKd6c  2021-11-12T15:59:46Z
# 2    UCpVm7bg6pXKo1Pr6k5kxG9A  ZADCqbRrNPM  2021-11-12T15:04:50Z
# 3    UCpVm7bg6pXKo1Pr6k5kxG9A  9EiFxvBdQsw  2021-11-12T14:59:52Z
# 4    UCpVm7bg6pXKo1Pr6k5kxG9A  vMZuibGSHXE  2021-11-12T14:59:52Z
# ..                        ...          ...                   ...
# 295  UCpVm7bg6pXKo1Pr6k5kxG9A  gHZcW1Vnh0s  2022-03-29T11:59:48Z
# 296  UCpVm7bg6pXKo1Pr6k5kxG9A  4W_P_Yxhnt0  2022-03-26T11:59:51Z
# 297  UCpVm7bg6pXKo1Pr6k5kxG9A  BtCLZbZSreY  2022-03-25T14:59:53Z
# 298  UCpVm7bg6pXKo1Pr6k5kxG9A  WoTzliYivSY  2022-03-24T13:29:47Z
# 299  UCpVm7bg6pXKo1Pr6k5kxG9A  ok8NYX1ddM8  2022-03-23T16:59:50Z
#
# [300 rows x 13 columns]

# %%
climate_words = [
    "climate",
    "global warming",
    "ice caps",
    "biodegradable",
    "carbon dioxide",
    "carbon monoxide",
    "coal",
    "oil",
    "petrol",
    "emission",
    "green energy",
    "environmental",
    "fossil fuel",
]

climate_str = '|'.join(climate_words)

climate_str
# Out:
# 'climate|global warming|ice caps|biodegradable|carbon dioxide|carbon monoxide|coal|oil|petrol|emission|green energy|environmental|fossil fuel'

# %%
environmental_df = vid_df[
    vid_df["title"].str.contains(climate_str) |
    vid_df["description"].str.contains(climate_str)
]

environmental_df.to_csv("../persist/cleansed/environmental_videos.csv", index=False)
